# %% [markdown]
# Implemented a Generator Class, which can generate vehicles and tasks for said vehicles with a poisson distribution.
# The second to last cell can be manipulated to try out the FIFO/ EDF scheduling resource

# %%
! pip install simpy
import simpy
! pip install numpy
import numpy as np
import random
random.seed(42)     #does this effect numpy aswell?
# Out:
# Requirement already satisfied: simpy in /Users/Ankai/.julia/conda/3/lib/python3.10/site-packages (4.1.1)
# Requirement already satisfied: numpy in /Users/Ankai/.julia/conda/3/lib/python3.10/site-packages (1.26.4)

# %%
class Tester: 

    def dalle(self,environment):
        while True: 
         yield environment.timeout(1)
         print("image")

# %%
class Task:

    def __init__(self, id, priority, duration, vehicle):

        self.id = id
        self.priority = priority
        self.duration = duration
        self.vehicle = vehicle
        self.time_spent_processing = 0


    def process(self, environment, resource):

        print(f'Task {self.id} came into existence at {environment.now}')
        environment.plan.append(f'Task {self.id} came into existence at {environment.now} with priority {self.priority} and duration {self.duration}')
        
        # keep requesting resource if processing duration hasn't been reached
        while(self.time_spent_processing < self.duration):

             if isinstance(resource, simpy.PriorityResource):
                req = resource.request(priority = self.priority)
             else:
                req = resource.request()

             with req as req:
            
                try:
                    #before receiving resource
                    print(f'Task {self.id} requesting at {environment.now} with priority {self.priority}')
                    yield req
                    #while holding resource
                    print(f'Task {self.id} got resource at {environment.now}')
                    environment.plan.append(f'Task {self.id} got resource at {environment.now}')
                    #try to timeout for the time needed to complete the task
                    yield environment.timeout(self.duration - self.time_spent_processing) 
                    print(f'Task {self.id} completed at {environment.now}')
                    #exit loop if processing is complete
                    self.vehicle.tasks_completed.append(self)
                    environment.total_tasks_completed += 1
                    break

                except simpy.Interrupt as interrupt:
                    by = interrupt.cause.by
                    usage = environment.now - interrupt.cause.usage_since
                    #save the processing progress of the task
                    self.time_spent_processing += usage
                    print(f'Task {self.id} got preempted by {by} at {environment.now} after {usage} time entities')

# %%
class Vehicle:

    def __init__(self, id, environment, assigned_tasks, resource, lambda_tasks, lambda_dwell_time, generator):

        self.id = id
        self.environment = environment
        self.assigned_tasks = assigned_tasks
        self.tasks_completed = []
        self.resource = resource
        self.lambda_tasks = lambda_tasks
        self.lambda_dwell_time = lambda_dwell_time      #do sth with this
        self.generator = generator
        self.inROI = True   #is vehicle in the intersection/ region of interest

        print(f'Vehicle {self.id} spawned in environment at time {self.environment.now}')

        #start lifecycle of every task that is created before simulation
        for task in assigned_tasks:     
            self.environment.total_task_count += 1              
            self.environment.process(task.process(self.environment, resource))

        #start task generator
        self.environment.process(self.generateTasks())

    def scheduleDeparture(self):
        yield self.environment.timeout(np.random.poisson(self.lambda_dwell_time))
        self.inROI = False

    def generateTasks(self):

        self.environment.process(self.scheduleDeparture())

        while self.inROI:

            priority = random.randint(0, 5)
            duration = random.randint(1, 5)
            yield self.environment.timeout(np.random.poisson(self.lambda_tasks)) 
            
            #add task to vehicle
            new_task = Task(self.environment.total_task_count, priority, duration, self)
            self.assigned_tasks.append(new_task)
            self.environment.total_task_count += 1

            #activate tasks lifecycle 
            self.environment.process(new_task.process(self.environment, self.resource))

            print(f'Vehicle {self.id} generated a new Task at {self.environment.now} - new Task id:{new_task.id}, priority: {new_task.priority} and duration: {new_task.duration}')

        self.generator.vehicles_present.remove(self)
        self.generator.vehicles_departed.append(self)
        print(f"vehicle {self.id} left the intersection and stopped generating tasks at {self.environment.now}")

# %%
class VehicleGenerator:

    def __init__(self, lambda_vehicles, lambda_tasks, lambda_dwell_time, environment, resource):

        self.lambda_vehicles = lambda_vehicles
        self.lambda_tasks = lambda_tasks
        self.lambda_dwell_time = lambda_dwell_time
        self.environment = environment
        self.resource = resource

        self.vehicles = []
        self.vehicles_present = []
        self.vehicles_departed = []
        self.vehicle_count = 0
        self.total_tasks = self.countTasks()
        #self.task_count # make task count function

        environment.process(self.generateVehicles())

    def generateVehicles(self):

        while True:
             
             yield self.environment.timeout(np.random.poisson(self.lambda_vehicles))

             new_vehicle = Vehicle(self.vehicle_count, self.environment,[], self.resource, self.lambda_tasks, self.lambda_dwell_time, self)
             self.vehicle_count +=1 
             self.vehicles.append(new_vehicle)
             self.vehicles_present.append(new_vehicle)


    def countTasks(self):

        total_tasks = 0

        for vehicle in self.vehicles:
            total_tasks += len(vehicle.assigned_tasks)
            
        return total_tasks

# %%
intersection = simpy.Environment()
intersection.plan = []
intersection.total_task_count = 0
intersection.total_tasks_completed = 0

#different resources to try out for different scheduling types 
cpuEDF = simpy.PreemptiveResource(intersection, capacity = 1)
cpuFifo = simpy.Resource(intersection)

poissonVehicles = 5  # time interval per vehicle
poissonTasks = 2.5   # time interval per task

poisson_dwell_time  = 30

generator = VehicleGenerator(poissonVehicles, poissonTasks, poisson_dwell_time, intersection, cpuEDF)     #switch out cpu resource for different scheduling results.

intersection.run(until = 60)
# Out:
# Vehicle 0 spawned in environment at time 2
# Vehicle 1 spawned in environment at time 6
# Vehicle 0 generated a new Task at 7 - new Task id:0, priority: 5 and duration: 1
# Task 0 came into existence at 7
# Task 0 requesting at 7 with priority 5
# Task 0 got resource at 7
# Vehicle 2 spawned in environment at time 8
# Vehicle 0 generated a new Task at 8 - new Task id:1, priority: 1 and duration: 2
# Task 1 came into existence at 8
# Task 1 requesting at 8 with priority 1
# Task 0 got preempted by <Process(process) object at 0x1180f6590> at 8 after 1 time entities
# Vehicle 0 generated a new Task at 8 - new Task id:2, priority: 5 and duration: 5
# Task 2 came into existence at 8
# Task 2 requesting at 8 with priority 5
# Task 1 got resource at 8
# Vehicle 1 generated a new Task at 9 - new Task id:3, priority: 0 and duration: 3
# Task 3 came into existence at 9
# Task 3 requesting at 9 with priority 0
# Task 1 got preempted by <Process(process) object at 0x1180f7940> at 9 after 1 time entities
# Task 1 requesting at 9 with priority 1
# Task 3 got resource at 9
# Vehicle 2 generated a new Task at 10 - new Task id:4, priority: 1 and duration: 1
# Task 4 came into existence at 10
# Task 4 requesting at 10 with priority 1
# Vehicle 3 spawned in environment at time 12
# Vehicle 0 generated a new Task at 12 - new Task id:5, priority: 0 and duration: 5
# Task 5 came into existence at 12
# Task 5 requesting at 12 with priority 0
# Task 3 completed at 12
# Task 5 got resource at 12
# Vehicle 2 generated a new Task at 13 - new Task id:6, priority: 0 and duration: 1
# Task 6 came into existence at 13
# Task 6 requesting at 13 with priority 0
# Vehicle 3 generated a new Task at 13 - new Task id:7, priority: 1 and duration: 2
# Task 7 came into existence at 13
# Task 7 requesting at 13 with priority 1
# Vehicle 1 generated a new Task at 14 - new Task id:8, priority: 3 and duration: 1
# Task 8 came into existence at 14
# Task 8 requesting at 14 with priority 3
# Vehicle 1 generated a new Task at 14 - new Task id:9, priority: 3 and duration: 2
# Task 9 came into existence at 14
# Task 9 requesting at 14 with priority 3
# Vehicle 0 generated a new Task at 15 - new Task id:10, priority: 4 and duration: 5
# Task 10 came into existence at 15
# Task 10 requesting at 15 with priority 4
# Vehicle 2 generated a new Task at 15 - new Task id:11, priority: 0 and duration: 5
# Task 11 came into existence at 15
# Task 11 requesting at 15 with priority 0
# Vehicle 3 generated a new Task at 15 - new Task id:12, priority: 1 and duration: 5
# Task 12 came into existence at 15
# Task 12 requesting at 15 with priority 1
# Vehicle 2 generated a new Task at 15 - new Task id:13, priority: 1 and duration: 4
# Task 13 came into existence at 15
# Task 13 requesting at 15 with priority 1
# Vehicle 1 generated a new Task at 16 - new Task id:14, priority: 3 and duration: 5
# Task 14 came into existence at 16
# Task 14 requesting at 16 with priority 3
# Task 5 completed at 17
# Vehicle 3 generated a new Task at 17 - new Task id:15, priority: 2 and duration: 3
# Task 15 came into existence at 17
# Task 15 requesting at 17 with priority 2
# Vehicle 2 generated a new Task at 17 - new Task id:16, priority: 1 and duration: 2
# Task 16 came into existence at 17
# Task 16 requesting at 17 with priority 1
# Vehicle 3 generated a new Task at 17 - new Task id:17, priority: 0 and duration: 4
# Task 17 came into existence at 17
# Task 17 requesting at 17 with priority 0
# Task 6 got resource at 17
# Vehicle 4 spawned in environment at time 18
# Vehicle 0 generated a new Task at 18 - new Task id:18, priority: 2 and duration: 1
# Task 18 came into existence at 18
# Task 18 requesting at 18 with priority 2
# Vehicle 1 generated a new Task at 18 - new Task id:19, priority: 2 and duration: 1
# Task 19 came into existence at 18
# Task 19 requesting at 18 with priority 2
# Vehicle 2 generated a new Task at 18 - new Task id:20, priority: 0 and duration: 3
# Task 20 came into existence at 18
# Task 20 requesting at 18 with priority 0
# Task 6 completed at 18
# Vehicle 4 generated a new Task at 18 - new Task id:21, priority: 2 and duration: 1
# Task 21 came into existence at 18
# Task 21 requesting at 18 with priority 2
# Vehicle 4 generated a new Task at 18 - new Task id:22, priority: 4 and duration: 3
# Task 22 came into existence at 18
# Task 22 requesting at 18 with priority 4
# Task 11 got resource at 18
# Vehicle 3 generated a new Task at 19 - new Task id:23, priority: 2 and duration: 5
# Task 23 came into existence at 19
# Task 23 requesting at 19 with priority 2
# Vehicle 3 generated a new Task at 20 - new Task id:24, priority: 2 and duration: 5
# Task 24 came into existence at 20
# Task 24 requesting at 20 with priority 2
# Vehicle 5 spawned in environment at time 21
# Vehicle 0 generated a new Task at 22 - new Task id:25, priority: 5 and duration: 4
# Task 25 came into existence at 22
# Task 25 requesting at 22 with priority 5
# Vehicle 2 generated a new Task at 22 - new Task id:26, priority: 3 and duration: 1
# Task 26 came into existence at 22
# Task 26 requesting at 22 with priority 3
# Vehicle 4 generated a new Task at 22 - new Task id:27, priority: 5 and duration: 5
# Task 27 came into existence at 22
# Task 27 requesting at 22 with priority 5
# Vehicle 2 generated a new Task at 22 - new Task id:28, priority: 1 and duration: 1
# Task 28 came into existence at 22
# Task 28 requesting at 22 with priority 1
# Vehicle 1 generated a new Task at 23 - new Task id:29, priority: 4 and duration: 1
# Task 29 came into existence at 23
# Task 29 requesting at 23 with priority 4
# Task 11 completed at 23
# Vehicle 5 generated a new Task at 23 - new Task id:30, priority: 0 and duration: 2
# Task 30 came into existence at 23
# Task 30 requesting at 23 with priority 0
# Task 17 got resource at 23
# Vehicle 3 generated a new Task at 24 - new Task id:31, priority: 1 and duration: 1
# Task 31 came into existence at 24
# Task 31 requesting at 24 with priority 1
# Vehicle 5 generated a new Task at 24 - new Task id:32, priority: 2 and duration: 2
# Task 32 came into existence at 24
# Task 32 requesting at 24 with priority 2
# Vehicle 5 generated a new Task at 24 - new Task id:33, priority: 5 and duration: 1
# Task 33 came into existence at 24
# Task 33 requesting at 24 with priority 5
# Vehicle 0 generated a new Task at 25 - new Task id:34, priority: 2 and duration: 1
# Task 34 came into existence at 25
# Task 34 requesting at 25 with priority 2
# Vehicle 2 generated a new Task at 25 - new Task id:35, priority: 3 and duration: 3
# Task 35 came into existence at 25
# Task 35 requesting at 25 with priority 3
# Vehicle 4 generated a new Task at 26 - new Task id:36, priority: 3 and duration: 3
# Task 36 came into existence at 26
# Task 36 requesting at 26 with priority 3
# Vehicle 3 generated a new Task at 26 - new Task id:37, priority: 5 and duration: 3
# Task 37 came into existence at 26
# Task 37 requesting at 26 with priority 5
# Vehicle 5 generated a new Task at 26 - new Task id:38, priority: 4 and duration: 2
# Task 38 came into existence at 26
# Task 38 requesting at 26 with priority 4
# Vehicle 0 generated a new Task at 26 - new Task id:39, priority: 4 and duration: 2
# Task 39 came into existence at 26
# Task 39 requesting at 26 with priority 4
# Vehicle 1 generated a new Task at 27 - new Task id:40, priority: 1 and duration: 3
# Task 40 came into existence at 27
# Task 40 requesting at 27 with priority 1
# Task 17 completed at 27
# Vehicle 2 generated a new Task at 27 - new Task id:41, priority: 1 and duration: 4
# Task 41 came into existence at 27
# Task 41 requesting at 27 with priority 1
# Vehicle 4 generated a new Task at 27 - new Task id:42, priority: 3 and duration: 3
# Task 42 came into existence at 27
# Task 42 requesting at 27 with priority 3
# Vehicle 1 generated a new Task at 27 - new Task id:43, priority: 0 and duration: 3
# Task 43 came into existence at 27
# Task 43 requesting at 27 with priority 0
# Task 20 got resource at 27
# Vehicle 3 generated a new Task at 28 - new Task id:44, priority: 5 and duration: 5
# Task 44 came into existence at 28
# Task 44 requesting at 28 with priority 5
# Vehicle 4 generated a new Task at 28 - new Task id:45, priority: 0 and duration: 2
# Task 45 came into existence at 28
# Task 45 requesting at 28 with priority 0
# Vehicle 5 generated a new Task at 29 - new Task id:46, priority: 1 and duration: 3
# Task 46 came into existence at 29
# Task 46 requesting at 29 with priority 1
# Vehicle 0 generated a new Task at 29 - new Task id:47, priority: 0 and duration: 2
# Task 47 came into existence at 29
# Task 47 requesting at 29 with priority 0
# Vehicle 6 spawned in environment at time 30
# Task 20 completed at 30
# Vehicle 4 generated a new Task at 30 - new Task id:48, priority: 3 and duration: 4
# Task 48 came into existence at 30
# Task 48 requesting at 30 with priority 3
# Vehicle 0 generated a new Task at 30 - new Task id:49, priority: 1 and duration: 2
# vehicle 0 left the intersection and stopped generating tasks at 30
# Task 49 came into existence at 30
# Task 49 requesting at 30 with priority 1
# Task 30 got resource at 30
# Vehicle 2 generated a new Task at 31 - new Task id:50, priority: 3 and duration: 3
# Task 50 came into existence at 31
# Task 50 requesting at 31 with priority 3
# Vehicle 3 generated a new Task at 31 - new Task id:51, priority: 1 and duration: 4
# Task 51 came into existence at 31
# Task 51 requesting at 31 with priority 1
# Vehicle 5 generated a new Task at 31 - new Task id:52, priority: 1 and duration: 3
# Task 52 came into existence at 31
# Task 52 requesting at 31 with priority 1
# Vehicle 6 generated a new Task at 31 - new Task id:53, priority: 5 and duration: 5
# Task 53 came into existence at 31
# Task 53 requesting at 31 with priority 5
# Vehicle 6 generated a new Task at 31 - new Task id:54, priority: 1 and duration: 2
# Task 54 came into existence at 31
# Task 54 requesting at 31 with priority 1
# Vehicle 1 generated a new Task at 32 - new Task id:55, priority: 4 and duration: 3
# vehicle 1 left the intersection and stopped generating tasks at 32
# Task 55 came into existence at 32
# Task 55 requesting at 32 with priority 4
# Vehicle 7 spawned in environment at time 32
# Vehicle 4 generated a new Task at 32 - new Task id:56, priority: 4 and duration: 3
# Task 56 came into existence at 32
# Task 56 requesting at 32 with priority 4
# Task 30 completed at 32
# Vehicle 6 generated a new Task at 32 - new Task id:57, priority: 4 and duration: 4
# Task 57 came into existence at 32
# Task 57 requesting at 32 with priority 4
# Task 43 got resource at 32
# Vehicle 3 generated a new Task at 33 - new Task id:58, priority: 3 and duration: 5
# Task 58 came into existence at 33
# Task 58 requesting at 33 with priority 3
# Vehicle 7 generated a new Task at 33 - new Task id:59, priority: 0 and duration: 1
# Task 59 came into existence at 33
# Task 59 requesting at 33 with priority 0
# Vehicle 6 generated a new Task at 33 - new Task id:60, priority: 5 and duration: 2
# Task 60 came into existence at 33
# Task 60 requesting at 33 with priority 5
# Vehicle 2 generated a new Task at 34 - new Task id:61, priority: 5 and duration: 5
# vehicle 2 left the intersection and stopped generating tasks at 34
# Task 61 came into existence at 34
# Task 61 requesting at 34 with priority 5
# Vehicle 8 spawned in environment at time 34
# Vehicle 4 generated a new Task at 34 - new Task id:62, priority: 0 and duration: 2
# Task 62 came into existence at 34
# Task 62 requesting at 34 with priority 0
# Vehicle 3 generated a new Task at 34 - new Task id:63, priority: 5 and duration: 4
# Task 63 came into existence at 34
# Task 63 requesting at 34 with priority 5
# Vehicle 4 generated a new Task at 34 - new Task id:64, priority: 4 and duration: 3
# Task 64 came into existence at 34
# Task 64 requesting at 34 with priority 4
# Task 43 completed at 35
# Vehicle 6 generated a new Task at 35 - new Task id:65, priority: 3 and duration: 4
# Task 65 came into existence at 35
# Task 65 requesting at 35 with priority 3
# Vehicle 8 generated a new Task at 35 - new Task id:66, priority: 4 and duration: 4
# Task 66 came into existence at 35
# Task 66 requesting at 35 with priority 4
# Vehicle 3 generated a new Task at 35 - new Task id:67, priority: 4 and duration: 1
# Task 67 came into existence at 35
# Task 67 requesting at 35 with priority 4
# Task 45 got resource at 35
# Vehicle 4 generated a new Task at 36 - new Task id:68, priority: 5 and duration: 1
# Task 68 came into existence at 36
# Task 68 requesting at 36 with priority 5
# Vehicle 7 generated a new Task at 37 - new Task id:69, priority: 4 and duration: 1
# Task 69 came into existence at 37
# Task 69 requesting at 37 with priority 4
# Vehicle 6 generated a new Task at 37 - new Task id:70, priority: 5 and duration: 5
# Task 70 came into existence at 37
# Task 70 requesting at 37 with priority 5
# Task 45 completed at 37
# Task 47 got resource at 37
# Vehicle 5 generated a new Task at 38 - new Task id:71, priority: 3 and duration: 3
# Task 71 came into existence at 38
# Task 71 requesting at 38 with priority 3
# Vehicle 8 generated a new Task at 38 - new Task id:72, priority: 2 and duration: 3
# Task 72 came into existence at 38
# Task 72 requesting at 38 with priority 2
# Vehicle 3 generated a new Task at 38 - new Task id:73, priority: 0 and duration: 3
# Task 73 came into existence at 38
# Task 73 requesting at 38 with priority 0
# Vehicle 4 generated a new Task at 38 - new Task id:74, priority: 3 and duration: 2
# Task 74 came into existence at 38
# Task 74 requesting at 38 with priority 3
# Vehicle 4 generated a new Task at 38 - new Task id:75, priority: 5 and duration: 5
# Task 75 came into existence at 38
# Task 75 requesting at 38 with priority 5
# Vehicle 7 generated a new Task at 39 - new Task id:76, priority: 3 and duration: 1
# Task 76 came into existence at 39
# Task 76 requesting at 39 with priority 3
# Vehicle 6 generated a new Task at 39 - new Task id:77, priority: 5 and duration: 3
# Task 77 came into existence at 39
# Task 77 requesting at 39 with priority 5
# Task 47 completed at 39
# Vehicle 3 generated a new Task at 39 - new Task id:78, priority: 5 and duration: 3
# vehicle 3 left the intersection and stopped generating tasks at 39
# Task 78 came into existence at 39
# Task 78 requesting at 39 with priority 5
# Task 59 got resource at 39
# Vehicle 9 spawned in environment at time 40
# Vehicle 4 generated a new Task at 40 - new Task id:79, priority: 4 and duration: 2
# Task 79 came into existence at 40
# Task 79 requesting at 40 with priority 4
# Task 59 completed at 40
# Task 62 got resource at 40
# Vehicle 8 generated a new Task at 41 - new Task id:80, priority: 4 and duration: 1
# Task 80 came into existence at 41
# Task 80 requesting at 41 with priority 4
# Vehicle 6 generated a new Task at 41 - new Task id:81, priority: 1 and duration: 5
# Task 81 came into existence at 41
# Task 81 requesting at 41 with priority 1
# Vehicle 4 generated a new Task at 41 - new Task id:82, priority: 4 and duration: 3
# Task 82 came into existence at 41
# Task 82 requesting at 41 with priority 4
# Vehicle 7 generated a new Task at 42 - new Task id:83, priority: 1 and duration: 3
# Task 83 came into existence at 42
# Task 83 requesting at 42 with priority 1
# Task 62 completed at 42
# Vehicle 6 generated a new Task at 42 - new Task id:84, priority: 0 and duration: 3
# Task 84 came into existence at 42
# Task 84 requesting at 42 with priority 0
# Task 73 got resource at 42
# Vehicle 10 spawned in environment at time 43
# Vehicle 8 generated a new Task at 43 - new Task id:85, priority: 3 and duration: 1
# Task 85 came into existence at 43
# Task 85 requesting at 43 with priority 3
# Vehicle 7 generated a new Task at 43 - new Task id:86, priority: 0 and duration: 2
# Task 86 came into existence at 43
# Task 86 requesting at 43 with priority 0
# Vehicle 6 generated a new Task at 43 - new Task id:87, priority: 4 and duration: 1
# Task 87 came into existence at 43
# Task 87 requesting at 43 with priority 4
# Vehicle 5 generated a new Task at 44 - new Task id:88, priority: 4 and duration: 2
# vehicle 5 left the intersection and stopped generating tasks at 44
# Task 88 came into existence at 44
# Task 88 requesting at 44 with priority 4
# Vehicle 9 generated a new Task at 44 - new Task id:89, priority: 4 and duration: 1
# Task 89 came into existence at 44
# Task 89 requesting at 44 with priority 4
# Vehicle 6 generated a new Task at 44 - new Task id:90, priority: 5 and duration: 4
# Task 90 came into existence at 44
# Task 90 requesting at 44 with priority 5
# Vehicle 4 generated a new Task at 45 - new Task id:91, priority: 2 and duration: 2
# Task 91 came into existence at 45
# Task 91 requesting at 45 with priority 2
# Task 73 completed at 45
# Vehicle 11 spawned in environment at time 45
# Vehicle 10 generated a new Task at 45 - new Task id:92, priority: 0 and duration: 4
# Task 92 came into existence at 45
# Task 92 requesting at 45 with priority 0
# Vehicle 6 generated a new Task at 45 - new Task id:93, priority: 2 and duration: 5
# Task 93 came into existence at 45
# Task 93 requesting at 45 with priority 2
# Task 84 got resource at 45
# Vehicle 8 generated a new Task at 46 - new Task id:94, priority: 0 and duration: 5
# Task 94 came into existence at 46
# Task 94 requesting at 46 with priority 0
# Vehicle 6 generated a new Task at 46 - new Task id:95, priority: 5 and duration: 3
# Task 95 came into existence at 46
# Task 95 requesting at 46 with priority 5
# Vehicle 8 generated a new Task at 46 - new Task id:96, priority: 3 and duration: 3
# Task 96 came into existence at 46
# Task 96 requesting at 46 with priority 3
# Vehicle 7 generated a new Task at 47 - new Task id:97, priority: 1 and duration: 2
# Task 97 came into existence at 47
# Task 97 requesting at 47 with priority 1
# Vehicle 11 generated a new Task at 47 - new Task id:98, priority: 1 and duration: 5
# Task 98 came into existence at 47
# Task 98 requesting at 47 with priority 1
# Vehicle 6 generated a new Task at 47 - new Task id:99, priority: 3 and duration: 5
# vehicle 6 left the intersection and stopped generating tasks at 47
# Task 99 came into existence at 47
# Task 99 requesting at 47 with priority 3
# Vehicle 8 generated a new Task at 47 - new Task id:100, priority: 3 and duration: 1
# Task 100 came into existence at 47
# Task 100 requesting at 47 with priority 3
# Vehicle 7 generated a new Task at 47 - new Task id:101, priority: 1 and duration: 2
# Task 101 came into existence at 47
# Task 101 requesting at 47 with priority 1
# Vehicle 9 generated a new Task at 48 - new Task id:102, priority: 4 and duration: 2
# Task 102 came into existence at 48
# Task 102 requesting at 48 with priority 4
# Vehicle 10 generated a new Task at 48 - new Task id:103, priority: 5 and duration: 2
# Task 103 came into existence at 48
# Task 103 requesting at 48 with priority 5
# Task 84 completed at 48
# Vehicle 9 generated a new Task at 48 - new Task id:104, priority: 4 and duration: 2
# Task 104 came into existence at 48
# Task 104 requesting at 48 with priority 4
# Task 86 got resource at 48
# Vehicle 11 generated a new Task at 49 - new Task id:105, priority: 0 and duration: 3
# Task 105 came into existence at 49
# Task 105 requesting at 49 with priority 0
# Vehicle 4 generated a new Task at 50 - new Task id:106, priority: 4 and duration: 4
# Task 106 came into existence at 50
# Task 106 requesting at 50 with priority 4
# Vehicle 8 generated a new Task at 50 - new Task id:107, priority: 0 and duration: 5
# Task 107 came into existence at 50
# Task 107 requesting at 50 with priority 0
# Task 86 completed at 50
# Vehicle 8 generated a new Task at 50 - new Task id:108, priority: 0 and duration: 5
# Task 108 came into existence at 50
# Task 108 requesting at 50 with priority 0
# Task 92 got resource at 50
# Vehicle 9 generated a new Task at 51 - new Task id:109, priority: 5 and duration: 1
# Task 109 came into existence at 51
# Task 109 requesting at 51 with priority 5
# Vehicle 11 generated a new Task at 51 - new Task id:110, priority: 1 and duration: 1
# Task 110 came into existence at 51
# Task 110 requesting at 51 with priority 1
# Vehicle 4 generated a new Task at 51 - new Task id:111, priority: 0 and duration: 3
# Task 111 came into existence at 51
# Task 111 requesting at 51 with priority 0
# Vehicle 12 spawned in environment at time 52
# Vehicle 7 generated a new Task at 52 - new Task id:112, priority: 4 and duration: 2
# Task 112 came into existence at 52
# Task 112 requesting at 52 with priority 4
# Vehicle 10 generated a new Task at 52 - new Task id:113, priority: 0 and duration: 1
# Task 113 came into existence at 52
# Task 113 requesting at 52 with priority 0
# Vehicle 8 generated a new Task at 52 - new Task id:114, priority: 1 and duration: 3
# Task 114 came into existence at 52
# Task 114 requesting at 52 with priority 1
# Vehicle 9 generated a new Task at 52 - new Task id:115, priority: 5 and duration: 4
# Task 115 came into existence at 52
# Task 115 requesting at 52 with priority 5
# Vehicle 11 generated a new Task at 52 - new Task id:116, priority: 1 and duration: 5
# Task 116 came into existence at 52
# Task 116 requesting at 52 with priority 1
# Vehicle 12 generated a new Task at 52 - new Task id:117, priority: 4 and duration: 4
# Task 117 came into existence at 52
# Task 117 requesting at 52 with priority 4
# Vehicle 7 generated a new Task at 53 - new Task id:118, priority: 1 and duration: 4
# Task 118 came into existence at 53
# Task 118 requesting at 53 with priority 1
# Task 92 completed at 54
# Vehicle 4 generated a new Task at 54 - new Task id:119, priority: 1 and duration: 5
# Task 119 came into existence at 54
# Task 119 requesting at 54 with priority 1
# Vehicle 8 generated a new Task at 54 - new Task id:120, priority: 0 and duration: 1
# vehicle 8 left the intersection and stopped generating tasks at 54
# Task 120 came into existence at 54
# Task 120 requesting at 54 with priority 0
# Vehicle 12 generated a new Task at 54 - new Task id:121, priority: 3 and duration: 4
# Task 121 came into existence at 54
# Task 121 requesting at 54 with priority 3
# Vehicle 4 generated a new Task at 54 - new Task id:122, priority: 5 and duration: 1
# Task 122 came into existence at 54
# Task 122 requesting at 54 with priority 5
# Task 94 got resource at 54
# Vehicle 9 generated a new Task at 55 - new Task id:123, priority: 5 and duration: 4
# Task 123 came into existence at 55
# Task 123 requesting at 55 with priority 5
# Vehicle 10 generated a new Task at 56 - new Task id:124, priority: 3 and duration: 2
# Task 124 came into existence at 56
# Task 124 requesting at 56 with priority 3
# Vehicle 11 generated a new Task at 56 - new Task id:125, priority: 2 and duration: 4
# Task 125 came into existence at 56
# Task 125 requesting at 56 with priority 2
# Vehicle 7 generated a new Task at 56 - new Task id:126, priority: 5 and duration: 1
# Task 126 came into existence at 56
# Task 126 requesting at 56 with priority 5
# Vehicle 12 generated a new Task at 57 - new Task id:127, priority: 0 and duration: 4
# Task 127 came into existence at 57
# Task 127 requesting at 57 with priority 0
# Vehicle 4 generated a new Task at 58 - new Task id:128, priority: 5 and duration: 3
# vehicle 4 left the intersection and stopped generating tasks at 58
# Task 128 came into existence at 58
# Task 128 requesting at 58 with priority 5
# Vehicle 9 generated a new Task at 58 - new Task id:129, priority: 0 and duration: 2
# Task 129 came into existence at 58
# Task 129 requesting at 58 with priority 0
# Vehicle 10 generated a new Task at 58 - new Task id:130, priority: 1 and duration: 2
# Task 130 came into existence at 58
# Task 130 requesting at 58 with priority 1
# Vehicle 7 generated a new Task at 58 - new Task id:131, priority: 1 and duration: 4
# Task 131 came into existence at 58
# Task 131 requesting at 58 with priority 1
# Vehicle 12 generated a new Task at 58 - new Task id:132, priority: 1 and duration: 3
# Task 132 came into existence at 58
# Task 132 requesting at 58 with priority 1
# Vehicle 13 spawned in environment at time 59
# Task 94 completed at 59
# Vehicle 10 generated a new Task at 59 - new Task id:133, priority: 0 and duration: 4
# Task 133 came into existence at 59
# Task 133 requesting at 59 with priority 0
# Task 105 got resource at 59

# %%
print(f"Total task count: {intersection.total_task_count}")
print(f"Number of tasks completed: {intersection.total_tasks_completed}")
print(f"Number of vehicles generated: {len(generator.vehicles)}")
print(f"Number of vehicles in intersection: {len(generator.vehicles_present)}")
print(f"Number of departed vehicles: {len(generator.vehicles_departed)}")

for v in generator.vehicles:
    print(f"Vehicle {v.id} had {len(v.assigned_tasks)} tasks assigned and {len(v.tasks_completed)} tasks completed ")

print("Task scheduling plan:")
# Out:
# Total task count: 134
# Number of tasks completed: 17
# Number of vehicles generated: 14
# Number of vehicles in intersection: 6
# Number of departed vehicles: 8
# Vehicle 0 had 11 tasks assigned and 2 tasks completed
# Vehicle 1 had 9 tasks assigned and 2 tasks completed
# Vehicle 2 had 12 tasks assigned and 3 tasks completed
# Vehicle 3 had 15 tasks assigned and 2 tasks completed
# Vehicle 4 had 21 tasks assigned and 2 tasks completed
# Vehicle 5 had 8 tasks assigned and 1 tasks completed
# Vehicle 6 had 14 tasks assigned and 1 tasks completed
# Vehicle 7 had 11 tasks assigned and 2 tasks completed
# Vehicle 8 had 11 tasks assigned and 1 tasks completed
# Vehicle 9 had 7 tasks assigned and 0 tasks completed
# Vehicle 10 had 6 tasks assigned and 1 tasks completed
# Vehicle 11 had 5 tasks assigned and 0 tasks completed
# Vehicle 12 had 4 tasks assigned and 0 tasks completed
# Vehicle 13 had 0 tasks assigned and 0 tasks completed
# Task scheduling plan:
